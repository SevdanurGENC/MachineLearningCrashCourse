# %%
#@title Import relevant modules
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from matplotlib import pyplot as plt
import seaborn as sns

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

print("Imported modules.")
# Out:
# Imported modules.

# %%
train_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")
train_df = train_df.reindex(np.random.permutation(train_df.index)) # shuffle the examples
test_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_test.csv")

# %%
#@title Convert raw values to their Z-scores 

# Calculate the Z-scores of each column in the training set:
train_df_mean = train_df.mean()
train_df_std = train_df.std()
train_df_norm = (train_df - train_df_mean)/train_df_std

# Calculate the Z-scores of each column in the test set.
test_df_mean = test_df.mean()
test_df_std = test_df.std()
test_df_norm = (test_df - test_df_mean)/test_df_std

print("Normalized the values.")
# Out:
# Normalized the values.

# %%
# Create an empty list that will eventually hold all created feature columns.
feature_columns = []

# We scaled all the columns, including latitude and longitude, into their
# Z scores. So, instead of picking a resolution in degrees, we're going
# to use resolution_in_Zs.  A resolution_in_Zs of 1 corresponds to 
# a full standard deviation. 
resolution_in_Zs = 0.3  # 3/10 of a standard deviation.

# Create a bucket feature column for latitude.
latitude_as_a_numeric_column = tf.feature_column.numeric_column("latitude")
latitude_boundaries = list(np.arange(int(min(train_df_norm['latitude'])), 
                                     int(max(train_df_norm['latitude'])), 
                                     resolution_in_Zs))
latitude = tf.feature_column.bucketized_column(latitude_as_a_numeric_column, latitude_boundaries)

# Create a bucket feature column for longitude.
longitude_as_a_numeric_column = tf.feature_column.numeric_column("longitude")
longitude_boundaries = list(np.arange(int(min(train_df_norm['longitude'])), 
                                      int(max(train_df_norm['longitude'])), 
                                      resolution_in_Zs))
longitude = tf.feature_column.bucketized_column(longitude_as_a_numeric_column, 
                                                longitude_boundaries)

# Create a feature cross of latitude and longitude.
latitude_x_longitude = tf.feature_column.crossed_column([latitude, longitude], hash_bucket_size=100)
crossed_feature = tf.feature_column.indicator_column(latitude_x_longitude)
feature_columns.append(crossed_feature)  

# Represent median_income as a floating-point value.
median_income = tf.feature_column.numeric_column("median_income")
feature_columns.append(median_income)

# Represent population as a floating-point value.
population = tf.feature_column.numeric_column("population")
feature_columns.append(population)

# Convert the list of feature columns into a layer that will later be fed into
# the model. 
my_feature_layer = tf.keras.layers.DenseFeatures(feature_columns)

# %%
#@title Define the plotting function.

def plot_the_loss_curve(epochs, mse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Mean Squared Error")

  plt.plot(epochs, mse, label="Loss")
  plt.legend()
  plt.ylim([mse.min()*0.95, mse.max() * 1.03])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %%
#@title Define functions to create and train a linear regression model
def create_model(my_learning_rate, feature_layer):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add the layer containing the feature columns to the model.
  model.add(feature_layer)

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Construct the layers into a model that TensorFlow can execute.
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.MeanSquaredError()])

  return model           


def train_model(model, dataset, epochs, batch_size, label_name):
  """Feed a dataset into the model in order to train it."""

  # Split the dataset into features and label.
  features = {name:np.array(value) for name, value in dataset.items()}
  label = np.array(features.pop(label_name))
  history = model.fit(x=features, y=label, batch_size=batch_size,
                      epochs=epochs, shuffle=True)

  # Get details that will be useful for plotting the loss curve.
  epochs = history.epoch
  hist = pd.DataFrame(history.history)
  rmse = hist["mean_squared_error"]

  return epochs, rmse   

print("Defined the create_model and train_model functions.")
# Out:
# Defined the create_model and train_model functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 15
batch_size = 1000
label_name = "median_house_value"

# Establish the model's topography.
my_model = create_model(learning_rate, my_feature_layer)

# Train the model on the normalized training set.
epochs, mse = train_model(my_model, train_df_norm, epochs, batch_size, label_name)
plot_the_loss_curve(epochs, mse)

test_features = {name:np.array(value) for name, value in test_df_norm.items()}
test_label = np.array(test_features.pop(label_name)) # isolate the label
print("\n Evaluate the linear regression model against the test set:")
my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)
# Out:
# WARNING:tensorflow:From C:\Users\Nano\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From C:\Users\Nano\Anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:4207: IndicatorColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From C:\Users\Nano\Anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:4262: CrossedColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# Epoch 1/15
# 17000/17000 [==============================] - 0s 21us/sample - loss: 0.5997 - mean_squared_error: 0.5997
# Epoch 2/15
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.4483 - mean_squared_error: 0.4483
# Epoch 3/15
# 17000/17000 [==============================] - 0s 12us/sample - loss: 0.3954 - mean_squared_error: 0.3954
# Epoch 4/15
# 17000/17000 [==============================] - 0s 10us/sample - loss: 0.3766 - mean_squared_error: 0.3766
# Epoch 5/15
# 17000/17000 [==============================] - 0s 9us/sample - loss: 0.3684 - mean_squared_error: 0.3684
# Epoch 6/15
# 17000/17000 [==============================] - 0s 13us/sample - loss: 0.3633 - mean_squared_error: 0.3633
# Epoch 7/15
# 17000/17000 [==============================] - 0s 16us/sample - loss: 0.3613 - mean_squared_error: 0.3613
# Epoch 8/15
# 17000/17000 [==============================] - 0s 19us/sample - loss: 0.3603 - mean_squared_error: 0.3603
# Epoch 9/15
# 17000/17000 [==============================] - 0s 12us/sample - loss: 0.3600 - mean_squared_error: 0.3600
# Epoch 10/15
# 17000/17000 [==============================] - 0s 10us/sample - loss: 0.3599 - mean_squared_error: 0.3599
# Epoch 11/15
# 17000/17000 [==============================] - 0s 10us/sample - loss: 0.3600 - mean_squared_error: 0.3600
# Epoch 12/15
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3597 - mean_squared_error: 0.3597
# Epoch 13/15
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3599 - mean_squared_error: 0.3599
# Epoch 14/15
# 17000/17000 [==============================] - 0s 10us/sample - loss: 0.3598 - mean_squared_error: 0.3598
# Epoch 15/15
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3599 - mean_squared_error: 0.3599
#  Evaluate the linear regression model against the test set:
# 3000/3000 [==============================] - 0s 37us/sample - loss: 0.3956 - mean_squared_error: 0.3956
# [0.39561885595321655, 0.39561886]

# %%
def create_model(my_learning_rate, my_feature_layer):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add the layer containing the feature columns to the model.
  model.add(my_feature_layer)

  # Describe the topography of the model by calling the tf.keras.layers.Dense
  # method once for each layer. We've specified the following arguments:
  #   * units specifies the number of nodes in this layer.
  #   * activation specifies the activation function (Rectified Linear Unit).
  #   * name is just a string that can be useful when debugging.

  # Define the first hidden layer with 20 nodes.   
  model.add(tf.keras.layers.Dense(units=20, 
                                  activation='relu', 
                                  name='Hidden1'))
  
  # Define the second hidden layer with 12 nodes. 
  model.add(tf.keras.layers.Dense(units=12, 
                                  activation='relu', 
                                  name='Hidden2'))
  
  # Define the output layer.
  model.add(tf.keras.layers.Dense(units=1,  
                                  name='Output'))                              
  
  model.compile(optimizer=tf.keras.optimizers.Adam(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.MeanSquaredError()])

  return model

# %%
def train_model(model, dataset, epochs, label_name,
                batch_size=None):
  """Train the model by feeding it data."""

  # Split the dataset into features and label.
  features = {name:np.array(value) for name, value in dataset.items()}
  label = np.array(features.pop(label_name))
  history = model.fit(x=features, y=label, batch_size=batch_size,
                      epochs=epochs, shuffle=True) 

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # To track the progression of training, gather a snapshot
  # of the model's mean squared error at each epoch. 
  hist = pd.DataFrame(history.history)
  mse = hist["mean_squared_error"]

  return epochs, mse

# %%
# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 20
batch_size = 1000

# Specify the label
label_name = "median_house_value"

# Establish the model's topography.
my_model = create_model(learning_rate, my_feature_layer)

# Train the model on the normalized training set. We're passing the entire
# normalized training set, but the model will only use the features
# defined by the feature_layer.
epochs, mse = train_model(my_model, train_df_norm, epochs, 
                          label_name, batch_size)
plot_the_loss_curve(epochs, mse)

# After building a model against the training set, test that model
# against the test set.
test_features = {name:np.array(value) for name, value in test_df_norm.items()}
test_label = np.array(test_features.pop(label_name)) # isolate the label
print("\n Evaluate the new model against the test set:")
my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)
# Out:
# WARNING:tensorflow:Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>>: AttributeError: module 'gast' has no attribute 'Num'
# Epoch 1/20
# 17000/17000 [==============================] - 0s 17us/sample - loss: 0.7807 - mean_squared_error: 0.7807
# Epoch 2/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3959 - mean_squared_error: 0.3959
# Epoch 3/20
# 17000/17000 [==============================] - 0s 9us/sample - loss: 0.3509 - mean_squared_error: 0.3509
# Epoch 4/20
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.3401 - mean_squared_error: 0.3401
# Epoch 5/20
# 17000/17000 [==============================] - 0s 9us/sample - loss: 0.3358 - mean_squared_error: 0.3358
# Epoch 6/20
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.3337 - mean_squared_error: 0.3337
# Epoch 7/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3311 - mean_squared_error: 0.3311
# Epoch 8/20
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3322 - mean_squared_error: 0.3322
# Epoch 9/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3297 - mean_squared_error: 0.3297
# Epoch 10/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3283 - mean_squared_error: 0.3283
# Epoch 11/20
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3254 - mean_squared_error: 0.3254
# Epoch 12/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3247 - mean_squared_error: 0.3247
# Epoch 13/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3249 - mean_squared_error: 0.3249
# Epoch 14/20
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3242 - mean_squared_error: 0.3242
# Epoch 15/20
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3246 - mean_squared_error: 0.3246
# Epoch 16/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3243 - mean_squared_error: 0.3243
# Epoch 17/20
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3233 - mean_squared_error: 0.3233
# Epoch 18/20
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3228 - mean_squared_error: 0.3228
# Epoch 19/20
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3221 - mean_squared_error: 0.3221
# Epoch 20/20
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3214 - mean_squared_error: 0.3214
#  Evaluate the new model against the test set:
# 3000/3000 [==============================] - 0s 39us/sample - loss: 0.3638 - mean_squared_error: 0.3638
# [0.36378761132558185, 0.3637876]

# %%
#@title Double-click for a possible solution

# The following "solution" uses L2 regularization to bring training loss
# and test loss closer to each other. Many, many other solutions are possible.


def create_model(my_learning_rate, my_feature_layer):
  """Create and compile a simple linear regression model."""

  # Discard any pre-existing version of the model.
  model = None

  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add the layer containing the feature columns to the model.
  model.add(my_feature_layer)

  # Describe the topography of the model. 

  # Implement L2 regularization in the first hidden layer.
  model.add(tf.keras.layers.Dense(units=20, 
                                  activation='relu',
                                  kernel_regularizer=tf.keras.regularizers.l2(0.04),
                                  name='Hidden1'))
  
  # Implement L2 regularization in the second hidden layer.
  model.add(tf.keras.layers.Dense(units=12, 
                                  activation='relu', 
                                  kernel_regularizer=tf.keras.regularizers.l2(0.04),
                                  name='Hidden2'))

  # Define the output layer.
  model.add(tf.keras.layers.Dense(units=1,  
                                  name='Output'))                              
  
  model.compile(optimizer=tf.keras.optimizers.Adam(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.MeanSquaredError()])

  return model     

# Call the new create_model function and the other (unchanged) functions.

# The following variables are the hyperparameters.
learning_rate = 0.007
epochs = 140
batch_size = 1000

label_name = "median_house_value"

# Establish the model's topography.
my_model = create_model(learning_rate, my_feature_layer)

# Train the model on the normalized training set.
epochs, mse = train_model(my_model, train_df_norm, epochs, 
                          label_name, batch_size)
plot_the_loss_curve(epochs, mse)

test_features = {name:np.array(value) for name, value in test_df_norm.items()}
test_label = np.array(test_features.pop(label_name)) # isolate the label
print("\n Evaluate the new model against the test set:")
my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)
# Out:
# WARNING:tensorflow:Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseFeatures.call of <tensorflow.python.feature_column.feature_column_v2.DenseFeatures object at 0x000001899F3EBD68>>: AttributeError: module 'gast' has no attribute 'Num'
# Epoch 1/140
# 17000/17000 [==============================] - 0s 24us/sample - loss: 1.8038 - mean_squared_error: 0.6960
# Epoch 2/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.7558 - mean_squared_error: 0.4348
# Epoch 3/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.5422 - mean_squared_error: 0.3901
# Epoch 4/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.4771 - mean_squared_error: 0.3803
# Epoch 5/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4514 - mean_squared_error: 0.3747
# Epoch 6/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4405 - mean_squared_error: 0.3718
# Epoch 7/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4351 - mean_squared_error: 0.3707
# Epoch 8/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4313 - mean_squared_error: 0.3693
# Epoch 9/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4288 - mean_squared_error: 0.3686
# Epoch 10/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4236 - mean_squared_error: 0.3653
# Epoch 11/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4212 - mean_squared_error: 0.3648
# Epoch 12/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4190 - mean_squared_error: 0.3629
# Epoch 13/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4164 - mean_squared_error: 0.3630
# Epoch 14/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.4146 - mean_squared_error: 0.3616
# Epoch 15/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4158 - mean_squared_error: 0.3644
# Epoch 16/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4134 - mean_squared_error: 0.3610
# Epoch 17/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4137 - mean_squared_error: 0.3626
# Epoch 18/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4115 - mean_squared_error: 0.3617
# Epoch 19/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4093 - mean_squared_error: 0.3587
# Epoch 20/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4095 - mean_squared_error: 0.3607
# Epoch 21/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4070 - mean_squared_error: 0.3574
# Epoch 22/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.4052 - mean_squared_error: 0.3571
# Epoch 23/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4035 - mean_squared_error: 0.3551
# Epoch 24/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4045 - mean_squared_error: 0.3568
# Epoch 25/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4019 - mean_squared_error: 0.3557
# Epoch 26/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4021 - mean_squared_error: 0.3553
# Epoch 27/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4035 - mean_squared_error: 0.3571
# Epoch 28/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4017 - mean_squared_error: 0.3564
# Epoch 29/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3982 - mean_squared_error: 0.3522
# Epoch 30/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3968 - mean_squared_error: 0.3524
# Epoch 31/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3989 - mean_squared_error: 0.3541
# Epoch 32/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3977 - mean_squared_error: 0.3537
# Epoch 33/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3964 - mean_squared_error: 0.3524
# Epoch 34/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3944 - mean_squared_error: 0.3512
# Epoch 35/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.4019 - mean_squared_error: 0.3588
# Epoch 36/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3973 - mean_squared_error: 0.3540
# Epoch 37/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3946 - mean_squared_error: 0.3522
# Epoch 38/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3936 - mean_squared_error: 0.3518
# Epoch 39/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3953 - mean_squared_error: 0.3535
# Epoch 40/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3929 - mean_squared_error: 0.3510
# Epoch 41/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3941 - mean_squared_error: 0.3530
# Epoch 42/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3922 - mean_squared_error: 0.3513
# Epoch 43/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3946 - mean_squared_error: 0.3533
# Epoch 44/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3955 - mean_squared_error: 0.3550
# Epoch 45/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3936 - mean_squared_error: 0.3533
# Epoch 46/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3915 - mean_squared_error: 0.3515
# Epoch 47/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3887 - mean_squared_error: 0.3488
# Epoch 48/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3894 - mean_squared_error: 0.3488
# Epoch 49/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3898 - mean_squared_error: 0.3511
# Epoch 50/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3899 - mean_squared_error: 0.3508
# Epoch 51/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3889 - mean_squared_error: 0.3488
# Epoch 52/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3899 - mean_squared_error: 0.3517
# Epoch 53/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3886 - mean_squared_error: 0.3501
# Epoch 54/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3974 - mean_squared_error: 0.3592
# Epoch 55/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3943 - mean_squared_error: 0.3559
# Epoch 56/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3885 - mean_squared_error: 0.3503
# Epoch 57/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3889 - mean_squared_error: 0.3515
# Epoch 58/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3875 - mean_squared_error: 0.3498
# Epoch 59/140
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.3895 - mean_squared_error: 0.3526
# Epoch 60/140
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.3870 - mean_squared_error: 0.3494
# Epoch 61/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3893 - mean_squared_error: 0.3518
# Epoch 62/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3875 - mean_squared_error: 0.3507
# Epoch 63/140
# 17000/17000 [==============================] - 0s 9us/sample - loss: 0.3860 - mean_squared_error: 0.3486
# Epoch 64/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3852 - mean_squared_error: 0.3484
# Epoch 65/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3845 - mean_squared_error: 0.3477
# Epoch 66/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3838 - mean_squared_error: 0.3481
# Epoch 67/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3838 - mean_squared_error: 0.3475
# Epoch 68/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3835 - mean_squared_error: 0.3468
# Epoch 69/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3831 - mean_squared_error: 0.3479
# Epoch 70/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3823 - mean_squared_error: 0.3466
# Epoch 71/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3823 - mean_squared_error: 0.3464
# Epoch 72/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3823 - mean_squared_error: 0.3469
# Epoch 73/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3829 - mean_squared_error: 0.3474
# Epoch 74/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3820 - mean_squared_error: 0.3471
# Epoch 75/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3823 - mean_squared_error: 0.3470
# Epoch 76/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3816 - mean_squared_error: 0.3469
# Epoch 77/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3833 - mean_squared_error: 0.3489
# Epoch 78/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3871 - mean_squared_error: 0.3526
# Epoch 79/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3848 - mean_squared_error: 0.3502
# Epoch 80/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3812 - mean_squared_error: 0.3471
# Epoch 81/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3813 - mean_squared_error: 0.3472
# Epoch 82/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3820 - mean_squared_error: 0.3477
# Epoch 83/140
# 17000/17000 [==============================] - 0s 11us/sample - loss: 0.3849 - mean_squared_error: 0.3508
# Epoch 84/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3820 - mean_squared_error: 0.3492
# Epoch 85/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3800 - mean_squared_error: 0.3467
# Epoch 86/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3807 - mean_squared_error: 0.3466
# Epoch 87/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3800 - mean_squared_error: 0.3467
# Epoch 88/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3796 - mean_squared_error: 0.3464
# Epoch 89/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3796 - mean_squared_error: 0.3460
# Epoch 90/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3785 - mean_squared_error: 0.3460
# Epoch 91/140
# 17000/17000 [==============================] - 0s 13us/sample - loss: 0.3791 - mean_squared_error: 0.3461
# Epoch 92/140
# 17000/17000 [==============================] - 0s 14us/sample - loss: 0.3786 - mean_squared_error: 0.3458
# Epoch 93/140
# 17000/17000 [==============================] - 0s 17us/sample - loss: 0.3783 - mean_squared_error: 0.3456
# Epoch 94/140
# 17000/17000 [==============================] - 0s 20us/sample - loss: 0.3782 - mean_squared_error: 0.3457
# Epoch 95/140
# 17000/17000 [==============================] - 0s 22us/sample - loss: 0.3776 - mean_squared_error: 0.3453
# Epoch 96/140
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.3781 - mean_squared_error: 0.3459
# Epoch 97/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3804 - mean_squared_error: 0.3479
# Epoch 98/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3836 - mean_squared_error: 0.3517
# Epoch 99/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3809 - mean_squared_error: 0.3491
# Epoch 100/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3785 - mean_squared_error: 0.3467
# Epoch 101/140
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.3782 - mean_squared_error: 0.3463
# Epoch 102/140
# 17000/17000 [==============================] - 0s 9us/sample - loss: 0.3792 - mean_squared_error: 0.3479
# Epoch 103/140
# 17000/17000 [==============================] - 0s 9us/sample - loss: 0.3800 - mean_squared_error: 0.3480
# Epoch 104/140
# 17000/17000 [==============================] - 0s 8us/sample - loss: 0.3814 - mean_squared_error: 0.3507
# Epoch 105/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3808 - mean_squared_error: 0.3492
# Epoch 106/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3766 - mean_squared_error: 0.3455
# Epoch 107/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3765 - mean_squared_error: 0.3452
# Epoch 108/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3767 - mean_squared_error: 0.3454
# Epoch 109/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3762 - mean_squared_error: 0.3453
# Epoch 110/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3770 - mean_squared_error: 0.3465
# Epoch 111/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3749 - mean_squared_error: 0.3437
# Epoch 112/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3752 - mean_squared_error: 0.3448
# Epoch 113/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3768 - mean_squared_error: 0.3458
# Epoch 114/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3749 - mean_squared_error: 0.3445
# Epoch 115/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3748 - mean_squared_error: 0.3439
# Epoch 116/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3762 - mean_squared_error: 0.3460
# Epoch 117/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3751 - mean_squared_error: 0.3450
# Epoch 118/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3750 - mean_squared_error: 0.3449
# Epoch 119/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3775 - mean_squared_error: 0.3474
# Epoch 120/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3747 - mean_squared_error: 0.3444
# Epoch 121/140
# 17000/17000 [==============================] - 0s 9us/sample - loss: 0.3748 - mean_squared_error: 0.3455
# Epoch 122/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3743 - mean_squared_error: 0.3440
# Epoch 123/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3758 - mean_squared_error: 0.3462
# Epoch 124/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3747 - mean_squared_error: 0.3450
# Epoch 125/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3744 - mean_squared_error: 0.3446
# Epoch 126/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3739 - mean_squared_error: 0.3442
# Epoch 127/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3731 - mean_squared_error: 0.3436
# Epoch 128/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3773 - mean_squared_error: 0.3482
# Epoch 129/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3744 - mean_squared_error: 0.3453
# Epoch 130/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3733 - mean_squared_error: 0.3442
# Epoch 131/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3730 - mean_squared_error: 0.3436
# Epoch 132/140
# 17000/17000 [==============================] - 0s 7us/sample - loss: 0.3736 - mean_squared_error: 0.3449
# Epoch 133/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3741 - mean_squared_error: 0.3449
# Epoch 134/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3734 - mean_squared_error: 0.3447
# Epoch 135/140
# 17000/17000 [==============================] - 0s 5us/sample - loss: 0.3738 - mean_squared_error: 0.3452
# Epoch 136/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3754 - mean_squared_error: 0.3464
# Epoch 137/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3725 - mean_squared_error: 0.3440
# Epoch 138/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3726 - mean_squared_error: 0.3442
# Epoch 139/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3740 - mean_squared_error: 0.3461
# Epoch 140/140
# 17000/17000 [==============================] - 0s 6us/sample - loss: 0.3720 - mean_squared_error: 0.3434
#  Evaluate the new model against the test set:
# 3000/3000 [==============================] - 0s 44us/sample - loss: 0.4061 - mean_squared_error: 0.3786
# [0.40613611539204914, 0.37862283]
