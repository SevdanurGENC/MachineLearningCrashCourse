# %%
#@title Import relevant modules
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# Import the dataset.
# verisetini ilgili yerden yukler
training_df = pd.read_csv(filepath_or_buffer="https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")

# Scale the label.
# etiket icin derleri standartlastiririz
training_df["median_house_value"] /= 1000.0

# Print the first rows of the pandas DataFrame.
# ilk birkac satiri ve sutun isimlerini pandas dataframe formunda gosteririz.
training_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5                66.9
# 1      1129.0       463.0            1.8                80.1
# 2       333.0       117.0            1.7                85.7
# 3       515.0       226.0            3.2                73.4
# 4       624.0       262.0            1.9                65.5

# %%
# Get statistics on the dataset.
# istatistiksel olarak bir tablo olusturur. 
training_df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9               207.3
# std        1147.9       384.5            1.9               116.0
# min           3.0         1.0            0.5                15.0
# 25%         790.0       282.0            2.6               119.4
# 50%        1167.0       409.0            3.5               180.4
# 75%        1721.0       605.2            4.8               265.0
# max       35682.0      6082.0           15.0               500.0

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the create_model and traing_model functions.")
# Out:
# Defined the create_model and traing_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 200 random points of the dataset.
  random_examples = training_df.sample(n=200)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = 10000
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 30
batch_size = 30

# Specify the feature and the label.
my_feature = "total_rooms"  # the total number of rooms on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# WARNING:tensorflow:From C:\Users\Nano\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/30
# 17000/17000 [==============================] - 1s 32us/sample - loss: 1701679.8112 - root_mean_squared_error: 1304.4839
# Epoch 2/30
# 17000/17000 [==============================] - 0s 27us/sample - loss: 27419.2063 - root_mean_squared_error: 165.5874
# Epoch 3/30
# 17000/17000 [==============================] - 0s 26us/sample - loss: 26753.9157 - root_mean_squared_error: 163.5662
# Epoch 4/30
# 17000/17000 [==============================] - 0s 29us/sample - loss: 26367.1677 - root_mean_squared_error: 162.3796
# Epoch 5/30
# 17000/17000 [==============================] - 1s 40us/sample - loss: 25498.1863 - root_mean_squared_error: 159.6815
# Epoch 6/30
# 17000/17000 [==============================] - 0s 27us/sample - loss: 25019.4652 - root_mean_squared_error: 158.1754
# Epoch 7/30
# 17000/17000 [==============================] - 0s 27us/sample - loss: 24172.9130 - root_mean_squared_error: 155.4764
# Epoch 8/30
# 17000/17000 [==============================] - 0s 27us/sample - loss: 23469.0505 - root_mean_squared_error: 153.1961
# Epoch 9/30
# 17000/17000 [==============================] - 1s 39us/sample - loss: 23167.7549 - root_mean_squared_error: 152.2096
# Epoch 10/30
# 17000/17000 [==============================] - 1s 60us/sample - loss: 22546.1402 - root_mean_squared_error: 150.1537
# Epoch 11/30
# 17000/17000 [==============================] - 1s 34us/sample - loss: 21860.7664 - root_mean_squared_error: 147.8538
# Epoch 12/30
# 17000/17000 [==============================] - 1s 46us/sample - loss: 21334.3320 - root_mean_squared_error: 146.0628
# Epoch 13/30
# 17000/17000 [==============================] - 1s 60us/sample - loss: 20975.9694 - root_mean_squared_error: 144.8308
# Epoch 14/30
# 17000/17000 [==============================] - 1s 51us/sample - loss: 20344.9231 - root_mean_squared_error: 142.6356
# Epoch 15/30
# 17000/17000 [==============================] - 1s 38us/sample - loss: 19898.1035 - root_mean_squared_error: 141.0607
# Epoch 16/30
# 17000/17000 [==============================] - 0s 28us/sample - loss: 19438.4390 - root_mean_squared_error: 139.4218
# Epoch 17/30
# 17000/17000 [==============================] - 1s 36us/sample - loss: 18991.0651 - root_mean_squared_error: 137.8081
# Epoch 18/30
# 17000/17000 [==============================] - 1s 45us/sample - loss: 18714.2174 - root_mean_squared_error: 136.7999
# Epoch 19/30
# 17000/17000 [==============================] - 0s 25us/sample - loss: 18260.7462 - root_mean_squared_error: 135.1323
# Epoch 20/30
# 17000/17000 [==============================] - 0s 25us/sample - loss: 17668.4847 - root_mean_squared_error: 132.9229
# Epoch 21/30
# 17000/17000 [==============================] - 0s 23us/sample - loss: 17536.1397 - root_mean_squared_error: 132.4241
# Epoch 22/30
# 17000/17000 [==============================] - 1s 34us/sample - loss: 17133.1995 - root_mean_squared_error: 130.8938
# Epoch 23/30
# 17000/17000 [==============================] - 1s 54us/sample - loss: 16852.0673 - root_mean_squared_error: 129.8155
# Epoch 24/30
# 17000/17000 [==============================] - 1s 54us/sample - loss: 16550.5880 - root_mean_squared_error: 128.6491
# Epoch 25/30
# 17000/17000 [==============================] - 1s 50us/sample - loss: 16356.7970 - root_mean_squared_error: 127.8937
# Epoch 26/30
# 17000/17000 [==============================] - 1s 46us/sample - loss: 16147.0538 - root_mean_squared_error: 127.0711
# Epoch 27/30
# 17000/17000 [==============================] - 0s 29us/sample - loss: 15946.8365 - root_mean_squared_error: 126.2808
# Epoch 28/30
# 17000/17000 [==============================] - 1s 46us/sample - loss: 15574.2438 - root_mean_squared_error: 124.7968
# Epoch 29/30
# 17000/17000 [==============================] - 1s 75us/sample - loss: 15479.3602 - root_mean_squared_error: 124.4161
# Epoch 30/30
# 17000/17000 [==============================] - 1s 69us/sample - loss: 15258.8888 - root_mean_squared_error: 123.5269
#
# The learned weight for your model is 0.0248
# The learned bias for your model is 132.5272

# %%
def predict_house_values(n, feature, label):
  """Predict house values based on a feature."""

  batch = training_df[feature][10000:10000 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature   label          predicted")
  print("  value   value          value")
  print("          in thousand$   in thousand$")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.0f %6.0f %15.0f" % (training_df[feature][i],
                                   training_df[label][i],
                                   predicted_values[i][0] ))

# %%
#@title Double-click to view a possible solution.

my_feature = "population" # Pick a feature other than "total_rooms"

# Possibly, experiment with the hyperparameters.
learning_rate = 0.05
epochs = 18
batch_size = 3

# Don't change anything below.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)

predict_house_values(10, my_feature, my_label)
# Out:
# Epoch 1/18
# 17000/17000 [==============================] - 4s 242us/sample - loss: 28537.9963 - root_mean_squared_error: 168.9319
# Epoch 2/18
# 17000/17000 [==============================] - 4s 233us/sample - loss: 19822.4138 - root_mean_squared_error: 140.7920
# Epoch 3/18
# 17000/17000 [==============================] - 4s 220us/sample - loss: 18068.2599 - root_mean_squared_error: 134.4183
# Epoch 4/18
# 17000/17000 [==============================] - 4s 241us/sample - loss: 18165.5304 - root_mean_squared_error: 134.7796
# Epoch 5/18
# 17000/17000 [==============================] - 4s 258us/sample - loss: 17828.5708 - root_mean_squared_error: 133.5236
# Epoch 6/18
# 17000/17000 [==============================] - 4s 261us/sample - loss: 18138.8060 - root_mean_squared_error: 134.6805
# Epoch 7/18
# 17000/17000 [==============================] - 4s 255us/sample - loss: 18193.0422 - root_mean_squared_error: 134.8815
# Epoch 8/18
# 17000/17000 [==============================] - 4s 262us/sample - loss: 17901.2293 - root_mean_squared_error: 133.7953
# Epoch 9/18
# 17000/17000 [==============================] - 4s 252us/sample - loss: 18393.3538 - root_mean_squared_error: 135.6221
# Epoch 10/18
# 17000/17000 [==============================] - 4s 250us/sample - loss: 18459.6240 - root_mean_squared_error: 135.8662
# Epoch 11/18
# 17000/17000 [==============================] - 4s 258us/sample - loss: 18300.6124 - root_mean_squared_error: 135.2796
# Epoch 12/18
# 17000/17000 [==============================] - 4s 255us/sample - loss: 17952.4941 - root_mean_squared_error: 133.9869
# Epoch 13/18
# 17000/17000 [==============================] - 5s 273us/sample - loss: 18661.7046 - root_mean_squared_error: 136.6079
# Epoch 14/18
# 17000/17000 [==============================] - 6s 333us/sample - loss: 18421.3176 - root_mean_squared_error: 135.7251
# Epoch 15/18
# 17000/17000 [==============================] - 5s 290us/sample - loss: 17921.0611 - root_mean_squared_error: 133.8695
# Epoch 16/18
# 17000/17000 [==============================] - 5s 286us/sample - loss: 18306.8480 - root_mean_squared_error: 135.3028
# Epoch 17/18
# 17000/17000 [==============================] - 4s 252us/sample - loss: 18539.4499 - root_mean_squared_error: 136.1597
# Epoch 18/18
# 17000/17000 [==============================] - 4s 264us/sample - loss: 18375.7779 - root_mean_squared_error: 135.5572
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#  1015     67             140
#  1129     80             108
#   333     86              90
#   515     73             152
#   624     66             120
#   671     74              83
#  1841     82             122
#   375     48             152
#  3134     58             192
#   787     48             122

# %%
#@title Double-click to view a possible solution to Task 4.

# Define a synthetic feature
training_df["rooms_per_person"] = training_df["total_rooms"] / training_df["population"]
my_feature = "rooms_per_person"

# Tune the hyperparameters.
learning_rate = 0.06
epochs = 24
batch_size = 30

# Don't change anything below this line.
my_model = build_model(learning_rate)
weight, bias, epochs, mae = train_model(my_model, training_df,
                                        my_feature, my_label,
                                        epochs, batch_size)
plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, mae)
predict_house_values(15, my_feature, my_label)
# Out:
# Epoch 1/24
# 17000/17000 [==============================] - 1s 34us/sample - loss: 39089.2977 - root_mean_squared_error: 197.7101
# Epoch 2/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 19086.6529 - root_mean_squared_error: 138.1544
# Epoch 3/24
# 17000/17000 [==============================] - 0s 27us/sample - loss: 15087.0256 - root_mean_squared_error: 122.8292
# Epoch 4/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 14820.9989 - root_mean_squared_error: 121.7415
# Epoch 5/24
# 17000/17000 [==============================] - 1s 31us/sample - loss: 14645.9576 - root_mean_squared_error: 121.0205
# Epoch 6/24
# 17000/17000 [==============================] - 1s 30us/sample - loss: 14470.6670 - root_mean_squared_error: 120.2941
# Epoch 7/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 14298.6990 - root_mean_squared_error: 119.5771
# Epoch 8/24
# 17000/17000 [==============================] - 0s 24us/sample - loss: 14150.1235 - root_mean_squared_error: 118.9543
# Epoch 9/24
# 17000/17000 [==============================] - 0s 27us/sample - loss: 14020.5553 - root_mean_squared_error: 118.4085
# Epoch 10/24
# 17000/17000 [==============================] - 0s 28us/sample - loss: 13945.7242 - root_mean_squared_error: 118.0920
# Epoch 11/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 13893.1099 - root_mean_squared_error: 117.8690
# Epoch 12/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 13820.9982 - root_mean_squared_error: 117.5627
# Epoch 13/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 13754.0822 - root_mean_squared_error: 117.2778
# Epoch 14/24
# 17000/17000 [==============================] - 0s 27us/sample - loss: 13724.4276 - root_mean_squared_error: 117.1513
# Epoch 15/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 13646.3187 - root_mean_squared_error: 116.8174
# Epoch 16/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 13637.0177 - root_mean_squared_error: 116.7777
# Epoch 17/24
# 17000/17000 [==============================] - 0s 29us/sample - loss: 13580.1216 - root_mean_squared_error: 116.5338
# Epoch 18/24
# 17000/17000 [==============================] - 1s 32us/sample - loss: 13547.6685 - root_mean_squared_error: 116.3944
# Epoch 19/24
# 17000/17000 [==============================] - 0s 27us/sample - loss: 13509.2736 - root_mean_squared_error: 116.2294
# Epoch 20/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 13462.2762 - root_mean_squared_error: 116.0271
# Epoch 21/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 13431.4559 - root_mean_squared_error: 115.8942
# Epoch 22/24
# 17000/17000 [==============================] - 0s 29us/sample - loss: 13419.8812 - root_mean_squared_error: 115.8442
# Epoch 23/24
# 17000/17000 [==============================] - 0s 27us/sample - loss: 13383.1699 - root_mean_squared_error: 115.6857
# Epoch 24/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 13400.1533 - root_mean_squared_error: 115.7590
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     6     67             187
#     7     80             199
#     2     86             193
#     3     73             209
#     2     66             185
#     2     74             223
#     2     82             209
#     2     48             221
#     2     58             286
#     2     48             212
#     2     86             222
#     2     62             232
#     2     49             223
#     2     70             217
#     2     45             209

# %%
training_df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude                 1.0      -0.9                -0.1          0.0
# latitude                 -0.9       1.0                 0.0         -0.0
# housing_median_age       -0.1       0.0                 1.0         -0.4
# total_rooms               0.0      -0.0                -0.4          1.0
# total_bedrooms            0.1      -0.1                -0.3          0.9
# population                0.1      -0.1                -0.3          0.9
# households                0.1      -0.1                -0.3          0.9
# median_income            -0.0      -0.1                -0.1          0.2
# median_house_value       -0.0      -0.1                 0.1          0.1
# rooms_per_person         -0.1       0.1                -0.1          0.1
#
#                     total_bedrooms  population  households  median_income  \
# longitude                      0.1         0.1         0.1           -0.0
# latitude                      -0.1        -0.1        -0.1           -0.1
# housing_median_age            -0.3        -0.3        -0.3           -0.1
# total_rooms                    0.9         0.9         0.9            0.2
# total_bedrooms                 1.0         0.9         1.0           -0.0
# population                     0.9         1.0         0.9           -0.0
# households                     1.0         0.9         1.0            0.0
# median_income                 -0.0        -0.0         0.0            1.0
# median_house_value             0.0        -0.0         0.1            0.7
# rooms_per_person               0.0        -0.1        -0.0            0.2
#
#                     median_house_value  rooms_per_person
# longitude                         -0.0              -0.1
# latitude                          -0.1               0.1
# housing_median_age                 0.1              -0.1
# total_rooms                        0.1               0.1
# total_bedrooms                     0.0               0.0
# population                        -0.0              -0.1
# households                         0.1              -0.0
# median_income                      0.7               0.2
# median_house_value                 1.0               0.2
# rooms_per_person                   0.2               1.0

# %%
#@title Double-click to view a possible solution.

my_feature = "median_income" # Pick a feature other than "total_rooms"

# Possibly, experiment with the hyperparameters.
learning_rate = 0.06
epochs = 24
batch_size = 30

# Don't change anything below.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)

predict_house_values(10, my_feature, my_label)
# Out:
# Epoch 1/24
# 17000/17000 [==============================] - 1s 34us/sample - loss: 26935.9775 - root_mean_squared_error: 164.1218
# Epoch 2/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 7283.8133 - root_mean_squared_error: 85.3453
# Epoch 3/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 7013.9637 - root_mean_squared_error: 83.7494
# Epoch 4/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 7015.8681 - root_mean_squared_error: 83.7608
# Epoch 5/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 7016.8473 - root_mean_squared_error: 83.7666
# Epoch 6/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 7015.4755 - root_mean_squared_error: 83.7584
# Epoch 7/24
# 17000/17000 [==============================] - 0s 28us/sample - loss: 7015.8578 - root_mean_squared_error: 83.7607
# Epoch 8/24
# 17000/17000 [==============================] - 1s 32us/sample - loss: 7014.6921 - root_mean_squared_error: 83.7538
# Epoch 9/24
# 17000/17000 [==============================] - 0s 29us/sample - loss: 7015.7395 - root_mean_squared_error: 83.7600
# Epoch 10/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 7016.1537 - root_mean_squared_error: 83.7625
# Epoch 11/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 7015.7537 - root_mean_squared_error: 83.7601
# Epoch 12/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 7016.0166 - root_mean_squared_error: 83.7617
# Epoch 13/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 7016.3390 - root_mean_squared_error: 83.7636
# Epoch 14/24
# 17000/17000 [==============================] - 0s 25us/sample - loss: 7014.4708 - root_mean_squared_error: 83.7524
# Epoch 15/24
# 17000/17000 [==============================] - 0s 27us/sample - loss: 7015.3797 - root_mean_squared_error: 83.7579
# Epoch 16/24
# 17000/17000 [==============================] - 0s 29us/sample - loss: 7016.2289 - root_mean_squared_error: 83.7629
# Epoch 17/24
# 17000/17000 [==============================] - 0s 29us/sample - loss: 7016.7044 - root_mean_squared_error: 83.7658
# Epoch 18/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 7013.6761 - root_mean_squared_error: 83.7477
# Epoch 19/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 7015.4531 - root_mean_squared_error: 83.7583
# Epoch 20/24
# 17000/17000 [==============================] - 1s 30us/sample - loss: 7015.7507 - root_mean_squared_error: 83.7601
# Epoch 21/24
# 17000/17000 [==============================] - 1s 31us/sample - loss: 7015.1324 - root_mean_squared_error: 83.7564
# Epoch 22/24
# 17000/17000 [==============================] - 0s 28us/sample - loss: 7015.9867 - root_mean_squared_error: 83.7615
# Epoch 23/24
# 17000/17000 [==============================] - 0s 26us/sample - loss: 7016.1286 - root_mean_squared_error: 83.7623
# Epoch 24/24
# 17000/17000 [==============================] - 0s 27us/sample - loss: 7015.2460 - root_mean_squared_error: 83.7570
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     1     67             135
#     2     80             213
#     2     86             155
#     3     73             133
#     2     66             155
#     3     74             149
#     3     82             459
#     2     48             262
#     2     58             148
#     2     48             223
