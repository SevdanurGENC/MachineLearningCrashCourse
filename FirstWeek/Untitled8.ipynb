# %%
#@title Import modules
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
train_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")
test_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_test.csv")

# %%
scale_factor = 1000.0

# Scale the training set's label.
train_df["median_house_value"] /= scale_factor 

# Scale the test set's label
test_df["median_house_value"] /= scale_factor

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model               


def train_model(model, df, feature, label, my_epochs, 
                my_batch_size=None, my_validation_split=0.1):
  """Feed a dataset into the model in order to train it."""

  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=my_batch_size,
                      epochs=my_epochs,
                      validation_split=my_validation_split)

  # Gather the model's trained weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
  epochs = history.epoch
  
  # Isolate the root mean squared error for each epoch.
  hist = pd.DataFrame(history.history)
  rmse = hist["root_mean_squared_error"]

  return epochs, rmse, history.history   

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
#@title Define the plotting function

def plot_the_loss_curve(epochs, mae_training, mae_validation):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
  plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
  plt.legend()
  
  # We're not going to plot the first epoch, since the loss on the first epoch
  # is often substantially greater than the loss for other epochs.
  merged_mae_lists = mae_training[1:] + mae_validation[1:]
  highest_loss = max(merged_mae_lists)
  lowest_loss = min(merged_mae_lists)
  delta = highest_loss - lowest_loss
  print(delta)

  top_of_y_axis = highest_loss + (delta * 0.05)
  bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
  plt.ylim([bottom_of_y_axis, top_of_y_axis])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 30
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split=0.2

# Identify the feature and the label.
my_feature="median_income"  # the median income on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions to build and train the model.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Train on 13600 samples, validate on 3400 samples
# Epoch 1/30
# 13600/13600 [==============================] - 0s 31us/sample - loss: 37366.6230 - root_mean_squared_error: 193.3045 - val_loss: 45309.8469 - val_root_mean_squared_error: 212.8611
# Epoch 2/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 21270.9320 - root_mean_squared_error: 145.8456 - val_loss: 26256.9785 - val_root_mean_squared_error: 162.0401
# Epoch 3/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 11239.1860 - root_mean_squared_error: 106.0150 - val_loss: 14155.4963 - val_root_mean_squared_error: 118.9769
# Epoch 4/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6979.2930 - root_mean_squared_error: 83.5422 - val_loss: 9294.8535 - val_root_mean_squared_error: 96.4098
# Epoch 5/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6513.8388 - root_mean_squared_error: 80.7084 - val_loss: 9380.9848 - val_root_mean_squared_error: 96.8555
# Epoch 6/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.8077 - root_mean_squared_error: 80.7082 - val_loss: 9196.1729 - val_root_mean_squared_error: 95.8967
# Epoch 7/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6513.8978 - root_mean_squared_error: 80.7087 - val_loss: 9249.4745 - val_root_mean_squared_error: 96.1742
# Epoch 8/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6513.6114 - root_mean_squared_error: 80.7070 - val_loss: 9253.4613 - val_root_mean_squared_error: 96.1949
# Epoch 9/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6513.5380 - root_mean_squared_error: 80.7065 - val_loss: 9271.0689 - val_root_mean_squared_error: 96.2864
# Epoch 10/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6511.5395 - root_mean_squared_error: 80.6941 - val_loss: 9296.3998 - val_root_mean_squared_error: 96.4178
# Epoch 11/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6513.6482 - root_mean_squared_error: 80.7072 - val_loss: 9213.8027 - val_root_mean_squared_error: 95.9886
# Epoch 12/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6514.1374 - root_mean_squared_error: 80.7102 - val_loss: 9285.0256 - val_root_mean_squared_error: 96.3588
# Epoch 13/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.2043 - root_mean_squared_error: 80.7044 - val_loss: 9161.1994 - val_root_mean_squared_error: 95.7142
# Epoch 14/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6513.9250 - root_mean_squared_error: 80.7089 - val_loss: 9213.7979 - val_root_mean_squared_error: 95.9885
# Epoch 15/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6512.7254 - root_mean_squared_error: 80.7015 - val_loss: 9319.9357 - val_root_mean_squared_error: 96.5398
# Epoch 16/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6513.8317 - root_mean_squared_error: 80.7083 - val_loss: 9262.9807 - val_root_mean_squared_error: 96.2444
# Epoch 17/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6512.4359 - root_mean_squared_error: 80.6997 - val_loss: 9227.6297 - val_root_mean_squared_error: 96.0606
# Epoch 18/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6513.9445 - root_mean_squared_error: 80.7090 - val_loss: 9293.4680 - val_root_mean_squared_error: 96.4026
# Epoch 19/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6513.3103 - root_mean_squared_error: 80.7051 - val_loss: 9246.2750 - val_root_mean_squared_error: 96.1576
# Epoch 20/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6512.9715 - root_mean_squared_error: 80.7030 - val_loss: 9241.4289 - val_root_mean_squared_error: 96.1324
# Epoch 21/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.9885 - root_mean_squared_error: 80.7093 - val_loss: 9233.8102 - val_root_mean_squared_error: 96.0927
# Epoch 22/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6512.1959 - root_mean_squared_error: 80.6982 - val_loss: 9087.5465 - val_root_mean_squared_error: 95.3286
# Epoch 23/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6514.8126 - root_mean_squared_error: 80.7144 - val_loss: 9246.1703 - val_root_mean_squared_error: 96.1570
# Epoch 24/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6512.8131 - root_mean_squared_error: 80.7020 - val_loss: 9348.7618 - val_root_mean_squared_error: 96.6890
# Epoch 25/30
# 13600/13600 [==============================] - 0s 11us/sample - loss: 6513.4403 - root_mean_squared_error: 80.7059 - val_loss: 9191.1412 - val_root_mean_squared_error: 95.8704
# Epoch 26/30
# 13600/13600 [==============================] - 0s 9us/sample - loss: 6513.6993 - root_mean_squared_error: 80.7075 - val_loss: 9236.6761 - val_root_mean_squared_error: 96.1076
# Epoch 27/30
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6512.9268 - root_mean_squared_error: 80.7027 - val_loss: 9185.9057 - val_root_mean_squared_error: 95.8431
# Epoch 28/30
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6513.8362 - root_mean_squared_error: 80.7083 - val_loss: 9329.1258 - val_root_mean_squared_error: 96.5874
# Epoch 29/30
# 13600/13600 [==============================] - 0s 12us/sample - loss: 6513.7243 - root_mean_squared_error: 80.7076 - val_loss: 9385.7482 - val_root_mean_squared_error: 96.8801
# Epoch 30/30
# 13600/13600 [==============================] - 0s 10us/sample - loss: 6514.4875 - root_mean_squared_error: 80.7124 - val_loss: 9241.0000 - val_root_mean_squared_error: 96.1301
# 81.34595

# %%
#@title Double-click to view the complete implementation.

# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 70
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split=0.15

# Identify the feature and the label.
my_feature="median_income"  # the median income on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Shuffle the examples.
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index)) 

# Invoke the functions to build and train the model. Train on the shuffled
# training set.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, shuffled_train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# Train on 14450 samples, validate on 2550 samples
# Epoch 1/70
# 14450/14450 [==============================] - 0s 24us/sample - loss: 44801.5030 - root_mean_squared_error: 211.6637 - val_loss: 32736.5767 - val_root_mean_squared_error: 180.9325
# Epoch 2/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 25271.5930 - root_mean_squared_error: 158.9704 - val_loss: 17301.4237 - val_root_mean_squared_error: 131.5349
# Epoch 3/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 13023.6175 - root_mean_squared_error: 114.1211 - val_loss: 8968.2113 - val_root_mean_squared_error: 94.7006
# Epoch 4/70
# 14450/14450 [==============================] - 0s 10us/sample - loss: 7688.9506 - root_mean_squared_error: 87.6867 - val_loss: 7052.0485 - val_root_mean_squared_error: 83.9765
# Epoch 5/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7008.0855 - root_mean_squared_error: 83.7143 - val_loss: 7072.9653 - val_root_mean_squared_error: 84.1009
# Epoch 6/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.1484 - root_mean_squared_error: 83.6968 - val_loss: 7071.5465 - val_root_mean_squared_error: 84.0925
# Epoch 7/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.8230 - root_mean_squared_error: 83.7008 - val_loss: 7058.1556 - val_root_mean_squared_error: 84.0128
# Epoch 8/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.2941 - root_mean_squared_error: 83.7036 - val_loss: 7060.5809 - val_root_mean_squared_error: 84.0273
# Epoch 9/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.2166 - root_mean_squared_error: 83.7031 - val_loss: 7057.3492 - val_root_mean_squared_error: 84.0080
# Epoch 10/70
# 14450/14450 [==============================] - 0s 11us/sample - loss: 7006.5097 - root_mean_squared_error: 83.7049 - val_loss: 7067.9870 - val_root_mean_squared_error: 84.0713
# Epoch 11/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.8622 - root_mean_squared_error: 83.7070 - val_loss: 7074.4775 - val_root_mean_squared_error: 84.1099
# Epoch 12/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.1742 - root_mean_squared_error: 83.6969 - val_loss: 7076.1951 - val_root_mean_squared_error: 84.1201
# Epoch 13/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.0097 - root_mean_squared_error: 83.6959 - val_loss: 7074.5313 - val_root_mean_squared_error: 84.1102
# Epoch 14/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7000.6661 - root_mean_squared_error: 83.6700 - val_loss: 7118.8932 - val_root_mean_squared_error: 84.3735
# Epoch 15/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.9855 - root_mean_squared_error: 83.7018 - val_loss: 7086.8800 - val_root_mean_squared_error: 84.1836
# Epoch 16/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.3731 - root_mean_squared_error: 83.7041 - val_loss: 7062.0380 - val_root_mean_squared_error: 84.0359
# Epoch 17/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.5776 - root_mean_squared_error: 83.7053 - val_loss: 7067.8046 - val_root_mean_squared_error: 84.0702
# Epoch 18/70
# 14450/14450 [==============================] - 0s 10us/sample - loss: 7005.7791 - root_mean_squared_error: 83.7005 - val_loss: 7083.6127 - val_root_mean_squared_error: 84.1642
# Epoch 19/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.8492 - root_mean_squared_error: 83.7069 - val_loss: 7078.8978 - val_root_mean_squared_error: 84.1362
# Epoch 20/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.7956 - root_mean_squared_error: 83.7066 - val_loss: 7062.8788 - val_root_mean_squared_error: 84.0409
# Epoch 21/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.0880 - root_mean_squared_error: 83.7024 - val_loss: 7069.2956 - val_root_mean_squared_error: 84.0791
# Epoch 22/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.6486 - root_mean_squared_error: 83.7057 - val_loss: 7067.3065 - val_root_mean_squared_error: 84.0673
# Epoch 23/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7004.8407 - root_mean_squared_error: 83.6949 - val_loss: 7057.1289 - val_root_mean_squared_error: 84.0067
# Epoch 24/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.3291 - root_mean_squared_error: 83.7038 - val_loss: 7081.3202 - val_root_mean_squared_error: 84.1506
# Epoch 25/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.8147 - root_mean_squared_error: 83.7067 - val_loss: 7081.8614 - val_root_mean_squared_error: 84.1538
# Epoch 26/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.1801 - root_mean_squared_error: 83.7029 - val_loss: 7062.0481 - val_root_mean_squared_error: 84.0360
# Epoch 27/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.7452 - root_mean_squared_error: 83.7063 - val_loss: 7075.7445 - val_root_mean_squared_error: 84.1174
# Epoch 28/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.7868 - root_mean_squared_error: 83.7066 - val_loss: 7061.4313 - val_root_mean_squared_error: 84.0323
# Epoch 29/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.7512 - root_mean_squared_error: 83.7063 - val_loss: 7076.0080 - val_root_mean_squared_error: 84.1190
# Epoch 30/70
# 14450/14450 [==============================] - 0s 11us/sample - loss: 7005.5621 - root_mean_squared_error: 83.6992 - val_loss: 7075.5935 - val_root_mean_squared_error: 84.1166
# Epoch 31/70
# 14450/14450 [==============================] - 0s 11us/sample - loss: 7006.2248 - root_mean_squared_error: 83.7032 - val_loss: 7066.5490 - val_root_mean_squared_error: 84.0628
# Epoch 32/70
# 14450/14450 [==============================] - 0s 11us/sample - loss: 7005.9290 - root_mean_squared_error: 83.7014 - val_loss: 7057.5933 - val_root_mean_squared_error: 84.0095
# Epoch 33/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7007.3245 - root_mean_squared_error: 83.7097 - val_loss: 7066.1399 - val_root_mean_squared_error: 84.0603
# Epoch 34/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.1227 - root_mean_squared_error: 83.7026 - val_loss: 7059.2235 - val_root_mean_squared_error: 84.0192
# Epoch 35/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7007.5296 - root_mean_squared_error: 83.7110 - val_loss: 7074.9093 - val_root_mean_squared_error: 84.1125
# Epoch 36/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7005.9887 - root_mean_squared_error: 83.7018 - val_loss: 7084.4080 - val_root_mean_squared_error: 84.1689
# Epoch 37/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7005.4313 - root_mean_squared_error: 83.6985 - val_loss: 7064.6569 - val_root_mean_squared_error: 84.0515
# Epoch 38/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.9352 - root_mean_squared_error: 83.7074 - val_loss: 7069.4449 - val_root_mean_squared_error: 84.0800
# Epoch 39/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7005.8905 - root_mean_squared_error: 83.7012 - val_loss: 7066.1353 - val_root_mean_squared_error: 84.0603
# Epoch 40/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.7309 - root_mean_squared_error: 83.7062 - val_loss: 7072.5217 - val_root_mean_squared_error: 84.0983
# Epoch 41/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.1326 - root_mean_squared_error: 83.7027 - val_loss: 7061.6588 - val_root_mean_squared_error: 84.0337
# Epoch 42/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.8038 - root_mean_squared_error: 83.7007 - val_loss: 7065.6081 - val_root_mean_squared_error: 84.0572
# Epoch 43/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7007.3673 - root_mean_squared_error: 83.7100 - val_loss: 7063.6608 - val_root_mean_squared_error: 84.0456
# Epoch 44/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7007.2696 - root_mean_squared_error: 83.7094 - val_loss: 7069.9213 - val_root_mean_squared_error: 84.0828
# Epoch 45/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.6587 - root_mean_squared_error: 83.7058 - val_loss: 7064.0593 - val_root_mean_squared_error: 84.0480
# Epoch 46/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.7039 - root_mean_squared_error: 83.7061 - val_loss: 7068.3960 - val_root_mean_squared_error: 84.0738
# Epoch 47/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7004.1845 - root_mean_squared_error: 83.6910 - val_loss: 7058.7043 - val_root_mean_squared_error: 84.0161
# Epoch 48/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.5983 - root_mean_squared_error: 83.6995 - val_loss: 7060.0462 - val_root_mean_squared_error: 84.0241
# Epoch 49/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.6888 - root_mean_squared_error: 83.7060 - val_loss: 7059.3491 - val_root_mean_squared_error: 84.0199
# Epoch 50/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7005.4039 - root_mean_squared_error: 83.6983 - val_loss: 7058.1448 - val_root_mean_squared_error: 84.0128
# Epoch 51/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.4533 - root_mean_squared_error: 83.7046 - val_loss: 7063.2899 - val_root_mean_squared_error: 84.0434
# Epoch 52/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.0076 - root_mean_squared_error: 83.6959 - val_loss: 7068.0252 - val_root_mean_squared_error: 84.0715
# Epoch 53/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.5967 - root_mean_squared_error: 83.7054 - val_loss: 7076.2457 - val_root_mean_squared_error: 84.1204
# Epoch 54/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.4250 - root_mean_squared_error: 83.7044 - val_loss: 7072.1035 - val_root_mean_squared_error: 84.0958
# Epoch 55/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.0812 - root_mean_squared_error: 83.6964 - val_loss: 7060.2049 - val_root_mean_squared_error: 84.0250
# Epoch 56/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7007.6350 - root_mean_squared_error: 83.7116 - val_loss: 7069.2467 - val_root_mean_squared_error: 84.0788
# Epoch 57/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.9409 - root_mean_squared_error: 83.7015 - val_loss: 7058.9060 - val_root_mean_squared_error: 84.0173
# Epoch 58/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.3031 - root_mean_squared_error: 83.7037 - val_loss: 7072.9370 - val_root_mean_squared_error: 84.1008
# Epoch 59/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7004.0307 - root_mean_squared_error: 83.6901 - val_loss: 7092.0901 - val_root_mean_squared_error: 84.2145
# Epoch 60/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.9704 - root_mean_squared_error: 83.7017 - val_loss: 7070.5034 - val_root_mean_squared_error: 84.0863
# Epoch 61/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.3658 - root_mean_squared_error: 83.7040 - val_loss: 7068.4153 - val_root_mean_squared_error: 84.0739
# Epoch 62/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.6744 - root_mean_squared_error: 83.7059 - val_loss: 7073.6504 - val_root_mean_squared_error: 84.1050
# Epoch 63/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.4163 - root_mean_squared_error: 83.6984 - val_loss: 7082.8396 - val_root_mean_squared_error: 84.1596
# Epoch 64/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7007.0829 - root_mean_squared_error: 83.7083 - val_loss: 7077.2972 - val_root_mean_squared_error: 84.1267
# Epoch 65/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.1370 - root_mean_squared_error: 83.7027 - val_loss: 7070.7091 - val_root_mean_squared_error: 84.0875
# Epoch 66/70
# 14450/14450 [==============================] - 0s 8us/sample - loss: 7006.2772 - root_mean_squared_error: 83.7035 - val_loss: 7063.6213 - val_root_mean_squared_error: 84.0454
# Epoch 67/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.6291 - root_mean_squared_error: 83.7056 - val_loss: 7065.4043 - val_root_mean_squared_error: 84.0560
# Epoch 68/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.2808 - root_mean_squared_error: 83.6976 - val_loss: 7083.1216 - val_root_mean_squared_error: 84.1613
# Epoch 69/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7005.6607 - root_mean_squared_error: 83.6998 - val_loss: 7069.2251 - val_root_mean_squared_error: 84.0787
# Epoch 70/70
# 14450/14450 [==============================] - 0s 9us/sample - loss: 7006.2705 - root_mean_squared_error: 83.7035 - val_loss: 7068.5099 - val_root_mean_squared_error: 84.0744
# 75.300446

# %%
x_test = test_df[my_feature]
y_test = test_df[my_label]

results = my_model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 3000/3000 [==============================] - 0s 10us/sample - loss: 7013.0608 - root_mean_squared_error: 83.7440
